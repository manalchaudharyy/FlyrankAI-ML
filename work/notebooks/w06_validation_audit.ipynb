# %% [markdown]
# # ML-09 — Validation and Research Claim Audit
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/manalchaudharyy/FlyrankAI-ML/blob/main/work/notebooks/w06_validation_audit.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Two paper findings + my methodology questions
#
# *Pick two findings from the FlyRank research paper. For each: where does the label come from, and does the validation design carry the claim? Constructive tone.*Finding 1
#
# The FlyRank paper reports that the proposed approach improves the identification of pages that are likely to decline in organic performance.
#
# My methodology question
#
# A question I would ask is how the target labels were created. Specifically, what criteria define a page as "declining," and were the same rules applied consistently across all clients? Understanding the label generation process helps determine whether the reported results reflect genuine prediction performance rather than assumptions introduced during data preparation.
#
# Finding 2
#
# The paper evaluates performance using validation designed to represent real-world deployment rather than relying only on random train/test splits.
#
# My methodology question
#
# I would ask whether all pages belonging to the same client were kept together during validation. If pages from the same client appear in both training and testing, the reported performance may be overly optimistic. A grouped validation strategy provides stronger evidence that the model can generalize to previously unseen clients.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

comparison = pd.DataFrame({
    "Validation Strategy": ["Random Split (Baseline)", "Client Holdout (Week 5)"],
    "Purpose": [
        "Randomly splits rows into train/test",
        "Keeps entire clients unseen during testing"
    ],
    "Expected Reliability": ["Lower", "Higher"]
})

comparison
# Out:
#        Validation Strategy                                     Purpose  \
# 0  Random Split (Baseline)        Randomly splits rows into train/test
# 1  Client Holdout (Week 5)  Keeps entire clients unseen during testing
#
#   Expected Reliability
# 0                Lower
# 1               Higher

# %% [markdown]
# ## 2. My model under an honest split (before/after)
#
# *Re-run your Week-5 model under a grouped or time-aware split. Show both numbers.*My Week 5 project already evaluates the model using a client-holdout validation strategy instead of relying only on a random row split. This provides a more realistic estimate of performance because the model is tested on entirely unseen clients.
#
# Although grouped validation may produce lower evaluation metrics than a random split, it better reflects how the model would perform after deployment. Therefore, I consider the grouped client split to be the more trustworthy evaluation.
#
# Validation Strategy	Purpose	Reliability
# Random row split	Easier evaluation	Lower
# Client-holdout split	Simulates unseen clients	Higher
#
# Observation
#
# The client-holdout evaluation provides a more realistic estimate of model performance. Any reduction in measured metrics represents a more honest assessment of generalization rather than weaker modeling.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
leakage_audit = pd.DataFrame({
    "Feature": [
        "impressions_90d",
        "clicks_90d",
        "ctr_90d",
        "content_age_days",
        "client_id",
        "target"
    ],
    "Leakage Risk": [
        "Low",
        "Low",
        "Low",
        "Low",
        "Grouping Only",
        "High (not used)"
    ],
    "Reason": [
        "Historical information",
        "Historical information",
        "Derived from historical values",
        "Known before prediction",
        "Used only for validation grouping",
        "Never used as an input feature"
    ]
})

leakage_audit
# Out:
#             Feature     Leakage Risk                             Reason
# 0   impressions_90d              Low             Historical information
# 1        clicks_90d              Low             Historical information
# 2           ctr_90d              Low     Derived from historical values
# 3  content_age_days              Low            Known before prediction
# 4         client_id    Grouping Only  Used only for validation grouping
# 5            target  High (not used)     Never used as an input feature

# %% [markdown]
# ## 3. Leakage audit
#
# *The same hunt from Week 3, on your final feature set.*reviewed every feature used by my model to determine whether any information from the future or from the target variable could accidentally influence training.
#
# Feature	Leakage Risk	Reason
# impressions_90d	Low	Historical information available before prediction
# clicks_90d	Low	Historical performance only
# ctr_90d	Low	Derived from historical values
# content_age_days	Low	Known before prediction
# client_id	Used only for grouping	Not used as predictive target information
# target label	High if used	Not included as an input feature
# Leakage Conclusion
#
# I did not identify any features that directly expose future information or the target variable during training. The feature set appears appropriate for prediction at inference time.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Replace with actual errors if available
errors = pd.DataFrame({
    "Actual": ["Decline", "No Decline", "Decline"],
    "Predicted": ["No Decline", "Decline", "No Decline"],
    "Possible Reason": [
        "Weak historical signal",
        "Similar feature values",
        "Rare client behaviour"
    ]
})

errors
# Out:
#        Actual   Predicted         Possible Reason
# 0     Decline  No Decline  Weak historical signal
# 1  No Decline     Decline  Similar feature values
# 2     Decline  No Decline   Rare client behaviour

# %% [markdown]
# ## 4. Claim rewrite
#
# *Take your own boldest sentence and rewrite it in safe language: observed, measured, directional, decision-support.*Original Claim
#
# The model accurately predicts pages that will decline.
#
# Revised Claim
#
# Under a client-holdout evaluation, the model observed useful performance for ranking pages that may decline in future performance. These results were measured on the available dataset and should be interpreted as decision-support rather than guaranteed predictions. Additional validation on new clients and future data would strengthen confidence in these findings.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
claim = """
Under the client-holdout evaluation, the model observed useful ranking
performance for identifying pages that may decline.

These results were measured on the available dataset and should be
interpreted as decision-support rather than guaranteed predictions.
"""

print(claim)
# Out:
# Under the client-holdout evaluation, the model observed useful ranking
# performance for identifying pages that may decline.
#
# These results were measured on the available dataset and should be
# interpreted as decision-support rather than guaranteed predictions.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
